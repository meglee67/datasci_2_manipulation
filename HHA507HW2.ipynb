# %% [markdown]
# <a href="https://colab.research.google.com/github/meglee67/datasci_2_manipulation/blob/main/HHA507HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Packages

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('healthcare_data_cleaning.csv')

# %% [markdown]
# ### Data Interpretation

# %% [markdown]
# ## Inspecting Shape

# %%
# Check the size and shape of the DataFrame
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 105000
# Number of columns: 20

# %%
# Check using the size function
print("Using size: ", df.size)
# Out:
# Using size:  2100000

# %%
# Check using shape
print(" Using shape alone: ", df.shape)
# Out:
#  Using shape alone:  (105000, 20)

# %% [markdown]
# ## Interpretation
#
# This looks to be large data with 105000 rows and 20 columns.

# %% [markdown]
# ## Previewing Data

# %%
# Lets look at the first 5 rows
df.head(5)
# Out:
#   Patient Age  Gender  City of Residence State of Residence Has Insurance  \
# 0          45   Other         West Brian           Kentucky           Yes
# 1          25  Female   East Jocelynfurt           Colorado            No
# 2          51   Other  South Lindseyland               Ohio           Yes
# 3          18  Female         Taylorfort       Pennsylvania           Yes
# 4          48  Female          Birdmouth            Montana            No
#
#   Visited Last Month Payment Method Preferred Doctor Disease Diagnosed  \
# 0                Yes      Insurance     Dr. Williams               Flu
# 1                Yes           Card      Dr. Johnson               Flu
# 2                 No           Cash     Dr. Williams          Covid-19
# 3            missing           Cash     Dr. Williams               Flu
# 4                 No      Insurance        Dr. Brown              None
#
#   Medication Prescribed Type of Appointment Average Heart Rate Average BP  \
# ...

# %%
# Then load in the last 5
df.tail(5)
# Out:
#        Patient Age  Gender City of Residence State of Residence Has Insurance  \
# 104995          74   Other      West Anthony           Oklahoma           Yes
# 104996          37    Male         Mckeetown               Utah           Yes
# 104997          51  Female  Lake Lisachester           Nebraska           Yes
# 104998     missing  Female      Heidiborough            missing           Yes
# 104999          45  Female     South Jeffrey      Massachusetts            No
#
#        Visited Last Month Payment Method Preferred Doctor Disease Diagnosed  \
# 104995                 No           Card     Dr. Williams          Covid-19
# 104996                 No           Cash        Dr. Jones          Covid-19
# 104997                Yes      Insurance     Dr. Williams           Allergy
# 104998                 No           Cash        Dr. Smith          Covid-19
# 104999                Yes           Cash        Dr. Brown           Allergy
#
# ...

# %%
# Take a look at a random sample
df.sample(5)
# Out:
#       Patient Age Gender City of Residence State of Residence Has Insurance  \
# 40795          30  Other        East James               Utah           Yes
# 88027     missing   Male           missing           Kentucky           Yes
# 64903          41   Male        New Denise            Indiana            No
# 54394          59   Male           missing           Nebraska            No
# 87910          47  Other  East Tiffanyview               Utah            No
#
#       Visited Last Month Payment Method Preferred Doctor Disease Diagnosed  \
# 40795                 No           Cash        Dr. Jones               Flu
# 88027                Yes           Card     Dr. Williams              Cold
# 64903                Yes      Insurance        Dr. Jones              None
# 54394                Yes           Card        Dr. Brown              Cold
# 87910                Yes      Insurance     Dr. Williams           missing
#
# ...
